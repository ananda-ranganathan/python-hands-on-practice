# %%
try:
    file=open('filehandleExp.txt','r')
    content = file.read()
    a=ab
    print(content)

except FileNotFoundError:
    print("The file does not exists")
except Exception as EXCEP1:
    print(EXCEP1)
finally:
    if 'file' in locals() or not file.closed():
        file.close()
        print("File Closed")
# Out:
# name 'ab' is not defined
# File Closed

# %%
print (1)
# Out:
# 1
