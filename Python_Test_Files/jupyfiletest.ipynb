# %% [markdown]
# Jupiter _.ipynb file run test

# %% [markdown]
# # Step 1 : conda creation and conda activate in parent path
# # --> S:\zenspaces\zen_python_for_data_science\_py_environments_libraries_
# ![image.png](attachment:image.png)
# # step 2 : after we can see the kernel selection--> python enviornment --> conda created python version under the below path
# # --> S:\zenspaces\zen_python_for_data_science
# ![image-2.png](attachment:image-2.png)

# %%
6*6
# Out:
# 36

# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
