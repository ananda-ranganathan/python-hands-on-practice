# %%
# Modules and Packages in Python 
# Definition: A module is a file containing Python definitions and statements.
# A package is a directory containing one or more modules.

# %%
import math
math.sqrt(4)
# Out:
# 2.0

# %%
from math import sqrt, pi # import sqrt and pi from math module 
print(sqrt(4)) # (square root(4))
print(sqrt(5))
print(sqrt(25))
print(pi)
# Out:
# 2.0
# 2.23606797749979
# 5.0
# 3.141592653589793

# %%
import numpy as np # import numpy as np (as (alias) np is a short hand for numpy)

# %%
import numpy as np # import numpy as np (as (alias) np is a short hand for numpy)
# inordered to download and install the numpy module we have to use the command pip install numpy
# it will download the latest version of numpy module and installed 
# it in our system so that above error will not occur

# %%
import numpy as np # import numpy as np (as (alias) np is a short hand for numpy)
# array
np.array([1,2,3,4,5,6,7])
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
from math import * # * means import all the functions that are available in the math module
print(sqrt(4))
print(sqrt(5))
print(sqrt(25))
print(pi)
# Out:
# 2.0
# 2.23606797749979
# 5.0
# 3.141592653589793

# %%
# call the packages that user created 
# package name : Python_Custom_User_Packages --> maths_calc

from python_custom_user_packages.maths_calc_custom_func import add_2_nums

add_2_nums(2,5)

# or 

from python_custom_user_packages import maths_calc_custom_func
maths_calc_custom_func.add_2_nums(3,7)

from python_custom_user_packages import maths_calc_custom_func
maths_calc_custom_func.multi_custom_func(2,22)

# if python not able to fetch the file then we have to create a __init__.py file or maths_calc.py file in the same folder
# Just save the file name as __init__.py and maths_calc.py file (ctrl+s)
# Restart the kernel by clicking the restart button in the toolbar or ctrl+shift+p and type restart kernel
# after run the file then it will show the output
# Out:
# 44
